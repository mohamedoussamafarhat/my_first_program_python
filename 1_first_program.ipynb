# %% [markdown]
# # FIRST PROGRAM
# La sec de fib 30 , 40 , 80

# %%
from IPython import display

# %%
display.Image("capturaaaa.png")

# %%
def f(n):
    if n<=1:
        return n
    else:
        return(f(n-1)+f(n-2))

# %%
f(10)
# Out:
# 55

# %%
pwd
# Out:
# '/home/jovyan/demo'
